# %%
import requests # pip install requests
from consumer_details import CONSUMER_KEY, CONSUMER_SECRET, USERNAME, PASSWORD
import pandas as pd # pip install pandas

from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
import psycopg2

conn = psycopg2.connect(database="Salesforce",
                        host="",
                        user="postgres",
                        password="vala2510",
                        port="5432")

# Generate Access Token
def generate_token():    
    payload = {
        'grant_type': 'password',
        'client_id': CONSUMER_KEY,
        'client_secret': CONSUMER_SECRET,
        'username': USERNAME,
        'password': PASSWORD
    }
    oauth_endpoint = '/services/oauth2/token'
    response = requests.post(DOMAIN + oauth_endpoint, data=payload)
    return response.json()

DOMAIN = 'https://dir0000007kzc2ai-dev-ed.develop.my.salesforce.com'
access_token = generate_token()['access_token']
headers = {
    'Authorization': 'Bearer ' + access_token
}
# print(access_token)
# Example 1. Run a SOQL query
def query(soql_query):
    try:
        # soql_query = 'SELECT name FROM opportunity'
        endpoint = '/services/data/v54.0/query/'
        records = []
        response = requests.get(DOMAIN + endpoint, headers=headers, params={'q': soql_query})
        total_size = response.json()['totalSize']
        records.extend(response.json()['records'])

        while not response.json()['done']:
            response = requests.get(DOMAIN + endpoint + response.json()['nextRecordsUrl'], headers=headers)
            records.extend(response.json()['records'])
        return {'record_size': total_size, 'records': records}
    except Exception as e:
        print(e)
        return

records = query('SELECT id, name, type FROM opportunity')
print(records)
df = pd.DataFrame(records['records'])
print(df)

# Example 2. Retrieve an object's metadata
def retrieve_object_metadata(object_api_name):
    response = requests.get(DOMAIN + f'/services/data/v56.0/sobjects/{object_api_name}/describe', headers=headers)
    return response.json()

object_id = 'account'
object_metadata = retrieve_object_metadata(object_id)
print(object_metadata)
df_metadata = pd.DataFrame(object_metadata['fields'])
df_metadata.to_csv('account metadata information.csv', index=False)
df_metadata.to_sql(name='opportunity', con=engine)
# Out:
# {'record_size': 31, 'records': [{'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8t3YAB'}, 'Id': '006IR00001Tj8t3YAB', 'Name': 'Dickenson Mobile Generators', 'Type': 'New Customer'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8t5YAB'}, 'Id': '006IR00001Tj8t5YAB', 'Name': 'United Oil Office Portable Generators', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8t8YAB'}, 'Id': '006IR00001Tj8t8YAB', 'Name': 'Express Logistics Standby Generator', 'Type': 'New Customer'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8t6YAB'}, 'Id': '006IR00001Tj8t6YAB', 'Name': 'GenePoint Standby Generator', 'Type': 'New Customer'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8t9YAB'}, 'Id': '006IR00001Tj8t9YAB', 'Name': 'Grand Hotels Kitchen Generator', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8t7YAB'}, 'Id': '006IR00001Tj8t7YAB', 'Name': 'United Oil Refinery Generators', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8t4YAB'}, 'Id': '006IR00001Tj8t4YAB', 'Name': 'United Oil SLA', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tAYAR'}, 'Id': '006IR00001Tj8tAYAR', 'Name': 'Grand Hotels Guest Portable Generators', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tBYAR'}, 'Id': '006IR00001Tj8tBYAR', 'Name': 'Edge Emergency Generator', 'Type': 'New Customer'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tCYAR'}, 'Id': '006IR00001Tj8tCYAR', 'Name': 'University of AZ Portable Generators', 'Type': 'New Customer'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tDYAR'}, 'Id': '006IR00001Tj8tDYAR', 'Name': 'Pyramid Emergency Generators', 'Type': None}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tEYAR'}, 'Id': '006IR00001Tj8tEYAR', 'Name': 'Express Logistics Portable Truck Generators', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tWYAR'}, 'Id': '006IR00001Tj8tWYAR', 'Name': 'GenePoint Lab Generators', 'Type': None}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tXYAR'}, 'Id': '006IR00001Tj8tXYAR', 'Name': 'GenePoint SLA', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tFYAR'}, 'Id': '006IR00001Tj8tFYAR', 'Name': 'United Oil Installations', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tGYAR'}, 'Id': '006IR00001Tj8tGYAR', 'Name': 'Edge Installation', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tHYAR'}, 'Id': '006IR00001Tj8tHYAR', 'Name': 'Edge SLA', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tIYAR'}, 'Id': '006IR00001Tj8tIYAR', 'Name': 'United Oil Installations', 'Type': 'Existing Customer - Upgrade'}, {'attributes': {'type': 'Opportunity', 'url': '/services/data/v54.0/sobjects/Opportunity/006IR00001Tj8tJYAR'}, 'Id': '006IR00001Tj8tJYAR', 'Name': 'Grand Hotels Generator Insta ...
#                                            attributes                  Id  \
# 0   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8t3YAB
# 1   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8t5YAB
# 2   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8t8YAB
# 3   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8t6YAB
# 4   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8t9YAB
# 5   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8t7YAB
# 6   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8t4YAB
# 7   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tAYAR
# 8   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tBYAR
# 9   {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tCYAR
# 10  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tDYAR
# 11  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tEYAR
# 12  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tWYAR
# 13  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tXYAR
# 14  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tFYAR
# 15  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tGYAR
# 16  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tHYAR
# 17  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tIYAR
# 18  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tJYAR
# 19  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tKYAR
# 20  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tLYAR
# 21  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tMYAR
# 22  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tNYAR
# 23  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tOYAR
# 24  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tPYAR
# 25  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tQYAR
# 26  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tRYAR
# 27  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tVYAR
# 28  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tSYAR
# 29  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tTYAR
# 30  {'type': 'Opportunity', 'url': '/services/data...  006IR00001Tj8tUYAR
#
#                                            Name  \
# 0                   Dickenson Mobile Generators
# 1         United Oil Office Portable Generators
# 2           Express Logistics Standby Generator
# 3                   GenePoint Standby Generator
# 4                Grand Hotels Kitchen Generator
# 5                United Oil Refinery Generators
# 6                                United Oil SLA
# 7        Grand Hotels Guest Portable Generators
# 8                      Edge Emergency Generator
# 9          University of AZ Portable Generators
# 10                 Pyramid Emergency Generators
# 11  Express Logistics Portable Truck Generators
# 12                     GenePoint Lab Generators
# 13                                GenePoint SLA
# 14                     United Oil Installations
# 15                            Edge Installation
# 16                                     Edge SLA
# 17                     United Oil Installations
# 18         Grand Hotels Generator Installations
# 19               United Oil Refinery Generators
# 20               University of AZ Installations
# 21                        Express Logistics SLA
# 22                         University of AZ SLA
# 23  Burlington Textiles Weaving Plant Generator
# 24                     United Oil Installations
# 25              United Oil Emergency Generators
# 26                             Grand Hotels SLA
# 27                United Oil Standby Generators
# 28            Grand Hotels Emergency Generators
# 29          United Oil Plant Standby Generators
# 30                     Edge Emergency Generator
#
#                                Type
# 0                      New Customer
# 1       Existing Customer - Upgrade
# 2                      New Customer
# 3                      New Customer
# 4       Existing Customer - Upgrade
# 5       Existing Customer - Upgrade
# 6       Existing Customer - Upgrade
# 7       Existing Customer - Upgrade
# 8                      New Customer
# 9                      New Customer
# 10                             None
# 11      Existing Customer - Upgrade
# 12                             None
# 13      Existing Customer - Upgrade
# 14      Existing Customer - Upgrade
# 15      Existing Customer - Upgrade
# 16      Existing Customer - Upgrade
# 17      Existing Customer - Upgrade
# 18      Existing Customer - Upgrade
# 19                     New Customer
# 20      Existing Customer - Upgrade
# 21      Existing Customer - Upgrade
# 22      Existing Customer - Upgrade
# 23                     New Customer
# 24      Existing Customer - Upgrade
# 25      Existing Customer - Upgrade
# 26      Existing Customer - Upgrade
# 27      Existing Customer - Upgrade
# 28                     New Customer
# 29      Existing Customer - Upgrade
# 30  Existing Customer - Replacement
# {'actionOverrides': [], 'activateable': False, 'associateEntityType': None, 'associateParentEntity': None, 'childRelationships': [{'cascadeDelete': True, 'childSObject': 'AIInsightValue', 'deprecatedAndHidden': False, 'field': 'SobjectLookupValueId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': None, 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'AIRecordInsight', 'deprecatedAndHidden': False, 'field': 'TargetId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': None, 'restrictedDelete': False}, {'cascadeDelete': False, 'childSObject': 'Account', 'deprecatedAndHidden': False, 'field': 'ParentId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'ChildAccounts', 'restrictedDelete': False}, {'cascadeDelete': False, 'childSObject': 'AccountChangeEvent', 'deprecatedAndHidden': False, 'field': 'ParentId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': None, 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'AccountCleanInfo', 'deprecatedAndHidden': False, 'field': 'AccountId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'AccountCleanInfos', 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'AccountContactRole', 'deprecatedAndHidden': False, 'field': 'AccountId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'AccountContactRoles', 'restrictedDelete': False}, {'cascadeDelete': False, 'childSObject': 'AccountContactRoleChangeEvent', 'deprecatedAndHidden': False, 'field': 'AccountId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': None, 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'AccountFeed', 'deprecatedAndHidden': False, 'field': 'ParentId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'Feeds', 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'AccountHistory', 'deprecatedAndHidden': False, 'field': 'AccountId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'Histories', 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'AccountPartner', 'deprecatedAndHidden': False, 'field': 'AccountFromId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'AccountPartnersFrom', 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'AccountPartner', 'deprecatedAndHidden': False, 'field': 'AccountToId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'AccountPartnersTo', 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'AccountShare', 'deprecatedAndHidden': False, 'field': 'AccountId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'Shares', 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'ActivityHistory', 'deprecatedAndHidden': False, 'field': 'AccountId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'ActivityHistories', 'restrictedDelete': False}, {'cascadeDelete': False, 'childSObject': 'AlternativePaymentMethod', 'deprecatedAndHidden': False, 'field': 'AccountId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'AlternativePaymentMethods', 'restrictedDelete': False}, {'cascadeDelete': True, 'childSObject': 'Asset', 'deprecatedAndHidden': False, 'field': 'AccountId', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'Assets', 'restrictedDelete': False}, {'cascadeDelete': False, 'childSObject': 'Asset', 'deprecatedAndHidden': False, 'field': 'AssetProvidedById', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'ProvidedAssets', 'restrictedDelete': False}, {'cascadeDelete': False, 'childSObject': 'Asset', 'deprecatedAndHidden': False, 'field': 'AssetServicedById', 'junctionIdListNames': [], 'junctionReferenceTo': [], 'relationshipName': 'ServicedAssets', 'res ...
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:919, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     918 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 919     cursor.executemany(statement, parameters)
#
# ProgrammingError: Error binding parameter 41: type 'list' is not supported
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[1], line 67
#      65 df_metadata = pd.DataFrame(object_metadata['fields'])
#      66 df_metadata.to_csv('account metadata information.csv', index=False)
# ---> 67 df_metadata.to_sql(name='opportunity', con=engine)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:3081, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
#    2887 Write records stored in a DataFrame to a SQL database.
#    2888
#    (...)
#    3077 [(1,), (None,), (2,)]
#    3078 """  # noqa: E501
#    3079 from pandas.io import sql
# -> 3081 return sql.to_sql(
#    3082     self,
#    3083     name,
#    3084     con,
#    3085     schema=schema,
#    3086     if_exists=if_exists,
#    3087     index=index,
#    3088     index_label=index_label,
#    3089     chunksize=chunksize,
#    3090     dtype=dtype,
#    3091     method=method,
#    3092 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:2021, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2009 sql_engine = get_engine(engine)
#    2011 table = self.prep_table(
#    2012     frame=frame,
#    2013     name=name,
#    (...)
#    2018     dtype=dtype,
#    2019 )
# -> 2021 total_inserted = sql_engine.insert_records(
#    2022     table=table,
#    2023     con=self.con,
#    2024     frame=frame,
#    2025     name=name,
#    2026     index=index,
#    2027     schema=schema,
#    2028     chunksize=chunksize,
#    2029     method=method,
#    2030     **engine_kwargs,
#    2031 )
#    2033 self.check_case_sensitive(name=name, schema=schema)
#    2034 return total_inserted
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1570, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1568 if re.search(msg, err_text):
#    1569     raise ValueError("inf cannot be used with MySQL") from err
# -> 1570 raise err
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1561, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1558 from sqlalchemy import exc
#    1560 try:
# -> 1561     return table.insert(chunksize=chunksize, method=method)
#    1562 except exc.StatementError as err:
#    1563     # GH34431
#    1564     # https://stackoverflow.com/a/67358288/6067848
#    1565     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1566     )|inf can not be used with MySQL"""
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1122, in SQLTable.insert(self, chunksize, method)
#    1119     break
#    1121 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1122 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1123 # GH 46891
#    1124 if num_inserted is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\sql\elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1936                 break
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#    1945     if self.dialect._has_events:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\default.py:919, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     918 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 919     cursor.executemany(statement, parameters)
#
# ProgrammingError: (sqlite3.ProgrammingError) Error binding parameter 41: type 'list' is not supported
# [SQL: INSERT INTO opportunity ("index", aggregatable, "aiPredictionField", "autoNumber", "byteLength", calculated, "calculatedFormula", "cascadeDelete", "caseSensitive", "compoundFieldName", "controllerName", createable, custom, "defaultValue", "defaultValueFormula", "defaultedOnCreate", "dependentPicklist", "deprecatedAndHidden", digits, "displayLocationInDecimal", encrypted, "externalId", "extraTypeInfo", filterable, "filteredLookupInfo", "formulaTreatNullNumberAsZero", groupable, "highScaleNumber", "htmlFormatted", "idLookup", "inlineHelpText", label, length, mask, "maskType", name, "nameField", "namePointing", nillable, permissionable, "picklistValues", "polymorphicForeignKey", precision, "queryByDistance", "referenceTargetField", "referenceTo", "relationshipName", "relationshipOrder", "restrictedDelete", "restrictedPicklist", scale, "searchPrefilterable", "soapType", sortable, type, "unique", updateable, "writeRequiresMasterRead") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: [(0, 1, 0, 0, 18, 0, None, 0, 0, None, None, 0, 0, None, None, 1, 0, 0, 0, 0, 0, 0, None, 1, None, 0, 1, 0, 0, 1, None, 'Account ID', 18, None, None, 'Id', 0, 0, 0, 0, [], 0, 0, 0, None, [], None, None, 0, 0, 0, 0, 'tns:ID', 1, 'id', 0, 0, 0), (1, 0, 0, 0, 0, 0, None, 0, 0, None, None, 0, 0, 0, None, 1, 0, 0, 0, 0, 0, 0, None, 1, None, 0, 1, 0, 0, 0, None, 'Deleted', 0, None, None, 'IsDeleted', 0, 0, 0, 0, [], 0, 0, 0, None, [], None, None, 0, 0, 0, 0, 'xsd:boolean', 1, 'boolean', 0, 0, 0), (2, 1, 0, 0, 18, 0, None, 0, 0, None, None, 0, 0, None, None, 0, 0, 0, 0, 0, 0, 0, None, 1, None, 0, 1, 0, 0, 0, None, 'Master Record ID', 18, None, None, 'MasterRecordId', 0, 0, 1, 0, [], 0, 0, 0, None, ['Account'], 'MasterRecord', None, 0, 0, 0, 0, 'tns:ID', 1, 'reference', 0, 0, 0), (3, 1, 0, 0, 765, 0, None, 0, 0, 'Name', None, 1, 0, None, None, 0, 0, 0, 0, 0, 0, 0, 'switchablepersonname', 1, None, 0, 1, 0, 0, 0, None, 'Account Name', 255, None, None, 'Name', 1, 0, 0, 0, [], 0, 0, 0, None, [], None, None, 0, 0, 0, 0, 'xsd:string', 1, 'string', 0, 1, 0), (4, 1, 0, 0, 765, 0, None, 0, 0, None, None, 1, 0, None, None, 0, 0, 0, 0, 0, 0, 0, None, 1, None, 0, 1, 0, 0, 0, None, 'Account Type', 255, None, None, 'Type', 0, 0, 1, 1, [{'active': True, 'defaultValue': False, 'label': 'Prospect', 'validFor': None, 'value': 'Prospect'}, {'active': True, 'defaultValue': False, 'label': ... (519 characters truncated) ... ner', 'validFor': None, 'value': 'Technology Partner'}, {'active': True, 'defaultValue': False, 'label': 'Other', 'validFor': None, 'value': 'Other'}], 0, 0, 0, None, [], None, None, 0, 0, 0, 0, 'xsd:string', 1, 'picklist', 0, 1, 0), (5, 1, 0, 0, 18, 0, None, 0, 0, None, None, 1, 0, None, None, 0, 0, 0, 0, 0, 0, 0, None, 1, None, 0, 1, 0, 0, 0, None, 'Parent Account ID', 18, None, None, 'ParentId', 0, 0, 1, 1, [], 0, 0, 0, None, ['Account'], 'Parent', None, 0, 0, 0, 1, 'tns:ID', 1, 'reference', 0, 1, 0), (6, 1, 0, 0, 765, 0, None, 0, 0, 'BillingAddress', None, 1, 0, None, None, 0, 0, 0, 0, 0, 0, 0, 'plaintextarea', 1, None, 0, 1, 0, 0, 0, None, 'Billing Street', 255, None, None, 'BillingStreet', 0, 0, 1, 1, [], 0, 0, 0, None, [], None, None, 0, 0, 0, 0, 'xsd:string', 1, 'textarea', 0, 1, 0), (7, 1, 0, 0, 120, 0, None, 0, 0, 'BillingAddress', None, 1, 0, None, None, 0, 0, 0, 0, 0, 0, 0, None, 1, None, 0, 1, 0, 0, 0, None, 'Billing City', 40, None, None, 'BillingCity', 0, 0, 1, 1, [], 0, 0, 0, None, [], None, None, 0, 0, 0, 0, 'xsd:string', 1, 'string', 0, 1, 0)  ... displaying 10 of 66 total bound parameter sets ...  (64, 1, 0, 0, 30, 0, None, 0, 0, None, None, 1, 1, None, None, 0, 0, 0, 0, 0, 0, 0, None, 1, None, 0, 1, 0, 0, 0, None, 'SLA Serial Number', 10, None, None, 'SLASerialNumber__c', 0, 0, 1, 1, [], 0, 0, 0, None, [], None, None, 0, 0, 0, 0, 'xsd:string', 1, 'string', 0, 1, 0), (65, 1, 0, 0, 0, 0, None, 0, 0, None, None, 1, 1, None, None, 0, 0, 0, 0, 0, 0, 0, None, 1, None, 0, 1, 0, 0, 0, None, 'SLA Expiration Date', 0, None, None, 'SLAExpirationDate__c', 0, 0, 1, 1, [], 0, 0, 0, None, [], None, None, 0, 0, 0, 0, 'xsd:date', 1, 'date', 0, 1, 0)]]
# (Background on this error at: https://sqlalche.me/e/20/f405)
